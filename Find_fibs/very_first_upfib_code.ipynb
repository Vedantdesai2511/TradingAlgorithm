# %%
import plotly.graph_objects as go

import pandas as pd
from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# To plot
# import matplotlib.pyplot as plt

# To import stock prices
import yfinance as yf  

import quandl

df = yf.download('UAL','2017-08-01', '2017-12-31')

df.to_excel("output.xlsx")
df = pd.read_excel (r'C:\Users\vedan\output.xlsx')

# a = 0
# counter = 0
# counter_positive = 0
# local_minimum = 0
# while a < len(df["Low"])-1:
#     diff = (df["Low"][a]) - (df["Low"][a+1])
#     if diff < 0:
#         counter = counter + 1 
#     else:
#         counter_positive = counter_positive + 1
#         if counter == 2 or counter > 2 and counter_positive > 2:
#             counter_positive = 0
#             if local_minimum == 0:
#                 local_minimum = df["Low"][a-2]
#             elif (local_minimum != 0) and (local_minimum > df["Low"][a]):
#                 local_minimum = df["Low"][a-2]
#     if a > 2:
#         print("local minimum:")
#         print(local_minimum)
#         print("Current Price:")
#         print(df["Low"][a])
#         if local_minimum > df["Low"][a]:
#             local_minimum = df["Low"][a]
#             print(local_minimum)
#             print( df["Low"][a])
#             a_max = a
#         else:
#             local_minimum = local_minimum
#     a = a + 1
# #     fig, ax = plt.subplots()
# #     ax.plot(df.Close, color='black')
# #     ax.axhline(local_minimum, linewidth=4, color='black')
# print(local_minimum)
# np.min(df['Low'])
# print("a_max: ")
# print(a_max)

a = 0
# a_max = 0
counter = 0
counter_positive = 0
local_maximum = 0
# new_df = 0
# df = df[:65] 
while a < len(df["High"])-1:
    print("hello")
    diff = (df["High"][a]) - (df["High"][a+1])
    if diff > 0:
        counter = counter + 1 
    else:
        counter_positive = counter_positive + 1
        if counter == 2 or counter > 2 and counter_positive > 2:
            counter_positive = 0
            counter = 0
            if local_maximum == 0:
                local_maximum = df["High"][a-2]
            elif (local_maximum != 0) and (local_maximum < df["High"][a]):
                local_maximum = df["High"][a-2]
    if a > a + 2:
        print("local maximum:")
        print(local_maximum)
        print("Current Price:")
        print( df["Low"][a])
        if local_maximum < df["High"][a]:
            local_maximum = df["High"][a]
            print(local_maximum)
            print(df["High"][a])
            print(local_maximum)
        else:
            local_maximum = local_maximum
    a = a + 1  

# a = a_max
# counter = 0
# counter_positive = 0
# local_minimum = 0
# while a < len(df["Low"])-1:
#     diff = (df["Low"][a]) - (df["Low"][a+1])
#     if diff < 0:
#         counter = counter + 1 
#     else:
#         counter_positive = counter_positive + 1
#         if counter == 2 or counter > 2 and counter_positive > 2:
#             counter_positive = 0
#             if local_minimum == 0:
#                 local_minimum = df["Low"][a-2]
#             elif (local_minimum != 0) and (local_minimum > df["Low"][a]):
#                 local_minimum = df["Low"][a-2]
#     if a > 2:
#         print("local minimum:")
#         print(local_minimum)
#         print("Current Price:")
#         print(df["Low"][a])
#         if local_minimum > df["Low"][a]:
#             local_minimum = df["Low"][a]
#             print(local_minimum)
#             print( df["Low"][a])
#         else:
#             local_minimum = local_minimum
#     a = a + 1
# #     fig, ax = plt.subplots()
# #     ax.plot(df.Close, color='black')
# #     ax.axhline(local_minimum, linewidth=4, color='black')
# print(local_minimum)
# np.min(df['Low'])

    
print(local_maximum)
print("Maximum:")
print(np.max(df['High']))
fig, ax = plt.subplots()
ax.plot(df["High"], color='black')
ax.plot(df["Low"], color='r')
ax.plot(df["Close"], color='g')
ax.axhline(local_maximum, linewidth=4, color='black')
ax.axhline(local_minimum, linewidth=4, color='black')
print(local_minimum)
# Out:
# [*********************100%***********************]  1 of 1 completed
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# 67.97000122070312
# Maximum:
# 69.62000274658203
# 56.5099983215332

# %%
df = yf.download('UAL','2017-08-01', '2017-12-31')

df.to_excel("output.xlsx")
df = pd.read_excel (r'C:\Users\vedan\output.xlsx')

a = 75
a_max = 0
counter = 0
counter_positive = 0
local_maximum = 0
new_df = 0
# df = df[:65] 
while a < len(df["High"])-1:
    diff = (df["High"][a]) - (df["High"][a+1])
    if diff > 0:
        counter = counter + 1 
    else:
        counter_positive = counter_positive + 1
        if counter == 2 or counter > 2 and counter_positive > 2:
            counter_positive = 0
            counter = 0
            if local_maximum == 0:
                local_maximum = df["High"][a-2]
            elif (local_maximum != 0) and (local_maximum < df["High"][a]):
                local_maximum = df["High"][a-2]
    if a > a + 2:
        print("local maximum:")
        print(local_maximum)
        print("Current Price:")
        print( df["Low"][a])
        if local_maximum < df["High"][a]:
            local_maximum = df["High"][a]
            print(local_maximum)
            print(df["High"][a])
            print(local_minimum)
        else:
            local_maximum = local_maximum
    a = a + 1
    
print(df["High"][75])

df_ = df[75:]
np.max(df_['High'])
# Out:
# [*********************100%***********************]  1 of 1 completed
# 57.68999862670898
# 67.98999786376953

# %%
local_maximum
# Out:
# 67.72000122070312

# %%
np.max(df['High'])
# Out:
# 69.62000274658203
